# %%
import numpy as np
import pandas as pd
from sail.models.sklearn.linear_model import SGDClassifier
from sail.pipeline import SAILPipeline
from sklearn.impute import SimpleImputer
from sail.transformers.river.preprocessing import StandardScaler

# %% [markdown]
# #### Load Data

# %%
X = pd.read_csv("../../datasets/agrawal.csv").head(5000)

y = X["class"]
X.drop("class", axis=1, inplace=True)

# %% [markdown]
# #### Model Definition

# %%
sgd_classifier = SGDClassifier(max_iter=100, tol=1e-3)

# %% [markdown]
# #### Create SAIL Pipeline

# %%
steps = [
    ("Imputer", SimpleImputer(missing_values=np.nan, strategy="mean")),
    ("standard_scalar", StandardScaler()),
    ("classifier", sgd_classifier),
]
sail_pipeline = SAILPipeline(steps=steps, verbosity_level=1)

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

# %% [markdown]
# #### Start Incremental Training

# %%
y_preds = []
y_true = []
batch_size = 1

for start in range(0, X_train.shape[0], batch_size):
    end = start + batch_size

    X = X_train.iloc[start:end]
    y = y_train.iloc[start:end]

    sail_pipeline.partial_fit(X, y, classifier__classes=[1, 0])
# Out:
#
# >> Epoch: 1 | Samples Seen: 0 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.012s, Batch Size=10, P_Score=0]
#
#
# >> Epoch: 2 | Samples Seen: 10 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.4]
#
#
# >> Epoch: 3 | Samples Seen: 20 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.55]
#
#
# >> Epoch: 4 | Samples Seen: 30 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.6]
#
#
# >> Epoch: 5 | Samples Seen: 40 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.65]
#
#
# >> Epoch: 6 | Samples Seen: 50 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.66]
#
#
# >> Epoch: 7 | Samples Seen: 60 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.065s, Batch Size=10, P_Score=0.65]
#
#
# >> Epoch: 8 | Samples Seen: 70 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.014s, Batch Size=10, P_Score=0.643]
#
#
# >> Epoch: 9 | Samples Seen: 80 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.014s, Batch Size=10, P_Score=0.613]
#
#
# >> Epoch: 10 | Samples Seen: 90 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.578]
#
#
# >> Epoch: 11 | Samples Seen: 100 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.59]
#
#
# >> Epoch: 12 | Samples Seen: 110 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.591]
#
#
# >> Epoch: 13 | Samples Seen: 120 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.558]
#
#
# >> Epoch: 14 | Samples Seen: 130 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 15 | Samples Seen: 140 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.536]
#
#
# >> Epoch: 16 | Samples Seen: 150 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.527]
#
#
# >> Epoch: 17 | Samples Seen: 160 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.022s, Batch Size=10, P_Score=0.512]
#
#
# >> Epoch: 18 | Samples Seen: 170 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.529]
#
#
# >> Epoch: 19 | Samples Seen: 180 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.528]
#
#
# >> Epoch: 20 | Samples Seen: 190 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.532]
#
#
# >> Epoch: 21 | Samples Seen: 200 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.53]
#
#
# >> Epoch: 22 | Samples Seen: 210 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.519]
#
#
# >> Epoch: 23 | Samples Seen: 220 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.518]
#
#
# >> Epoch: 24 | Samples Seen: 230 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.53]
#
#
# >> Epoch: 25 | Samples Seen: 240 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.521]
#
#
# >> Epoch: 26 | Samples Seen: 250 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.52]
#
#
# >> Epoch: 27 | Samples Seen: 260 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.034s, Batch Size=10, P_Score=0.523]
#
#
# >> Epoch: 28 | Samples Seen: 270 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.522]
#
#
# >> Epoch: 29 | Samples Seen: 280 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.525]
#
#
# >> Epoch: 30 | Samples Seen: 290 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.531]
#
#
# >> Epoch: 31 | Samples Seen: 300 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.537]
#
#
# >> Epoch: 32 | Samples Seen: 310 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.545]
#
#
# >> Epoch: 33 | Samples Seen: 320 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.544]
#
#
# >> Epoch: 34 | Samples Seen: 330 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.545]
#
#
# >> Epoch: 35 | Samples Seen: 340 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.547]
#
#
# >> Epoch: 36 | Samples Seen: 350 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.543]
#
#
# >> Epoch: 37 | Samples Seen: 360 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.539]
#
#
# >> Epoch: 38 | Samples Seen: 370 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.543]
#
#
# >> Epoch: 39 | Samples Seen: 380 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.542]
#
#
# >> Epoch: 40 | Samples Seen: 390 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.546]
#
#
# >> Epoch: 41 | Samples Seen: 400 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.547]
#
#
# >> Epoch: 42 | Samples Seen: 410 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.018s, Batch Size=10, P_Score=0.549]
#
#
# >> Epoch: 43 | Samples Seen: 420 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.545]
#
#
# >> Epoch: 44 | Samples Seen: 430 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.549]
#
#
# >> Epoch: 45 | Samples Seen: 440 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.555]
#
#
# >> Epoch: 46 | Samples Seen: 450 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.556]
#
#
# >> Epoch: 47 | Samples Seen: 460 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.559]
#
#
# >> Epoch: 48 | Samples Seen: 470 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 49 | Samples Seen: 480 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 50 | Samples Seen: 490 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 51 | Samples Seen: 500 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.047s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 52 | Samples Seen: 510 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 53 | Samples Seen: 520 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.012s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 54 | Samples Seen: 530 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.56]
#
#
# >> Epoch: 55 | Samples Seen: 540 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.559]
#
#
# >> Epoch: 56 | Samples Seen: 550 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.023s, Batch Size=10, P_Score=0.56]
#
#
# >> Epoch: 57 | Samples Seen: 560 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 58 | Samples Seen: 570 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.011s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 59 | Samples Seen: 580 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 60 | Samples Seen: 590 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.033s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 61 | Samples Seen: 600 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.017s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 62 | Samples Seen: 610 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 63 | Samples Seen: 620 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 64 | Samples Seen: 630 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 65 | Samples Seen: 640 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.012s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 66 | Samples Seen: 650 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.010s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 67 | Samples Seen: 660 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 68 | Samples Seen: 670 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.56]
#
#
# >> Epoch: 69 | Samples Seen: 680 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.56]
#
#
# >> Epoch: 70 | Samples Seen: 690 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.022s, Batch Size=10, P_Score=0.558]
#
#
# >> Epoch: 71 | Samples Seen: 700 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.556]
#
#
# >> Epoch: 72 | Samples Seen: 710 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.011s, Batch Size=10, P_Score=0.555]
#
#
# >> Epoch: 73 | Samples Seen: 720 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.557]
#
#
# >> Epoch: 74 | Samples Seen: 730 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.553]
#
#
# >> Epoch: 75 | Samples Seen: 740 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.551]
#
#
# >> Epoch: 76 | Samples Seen: 750 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.552]
#
#
# >> Epoch: 77 | Samples Seen: 760 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.551]
#
#
# >> Epoch: 78 | Samples Seen: 770 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.552]
#
#
# >> Epoch: 79 | Samples Seen: 780 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.553]
#
#
# >> Epoch: 80 | Samples Seen: 790 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.554]
#
#
# >> Epoch: 81 | Samples Seen: 800 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.554]
#
#
# >> Epoch: 82 | Samples Seen: 810 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.553]
#
#
# >> Epoch: 83 | Samples Seen: 820 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.555]
#
#
# >> Epoch: 84 | Samples Seen: 830 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.555]
#
#
# >> Epoch: 85 | Samples Seen: 840 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.556]
#
#
# >> Epoch: 86 | Samples Seen: 850 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.555]
#
#
# >> Epoch: 87 | Samples Seen: 860 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.56]
#
#
# >> Epoch: 88 | Samples Seen: 870 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 89 | Samples Seen: 880 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 90 | Samples Seen: 890 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 91 | Samples Seen: 900 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 92 | Samples Seen: 910 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 93 | Samples Seen: 920 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 94 | Samples Seen: 930 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 95 | Samples Seen: 940 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 96 | Samples Seen: 950 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.566]
#
#
# >> Epoch: 97 | Samples Seen: 960 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 98 | Samples Seen: 970 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.010s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 99 | Samples Seen: 980 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 100 | Samples Seen: 990 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 101 | Samples Seen: 1000 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 102 | Samples Seen: 1010 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 103 | Samples Seen: 1020 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.037s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 104 | Samples Seen: 1030 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 105 | Samples Seen: 1040 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.030s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 106 | Samples Seen: 1050 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 107 | Samples Seen: 1060 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 108 | Samples Seen: 1070 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 109 | Samples Seen: 1080 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 110 | Samples Seen: 1090 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 111 | Samples Seen: 1100 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 112 | Samples Seen: 1110 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 113 | Samples Seen: 1120 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 114 | Samples Seen: 1130 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 115 | Samples Seen: 1140 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.013s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 116 | Samples Seen: 1150 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 117 | Samples Seen: 1160 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.011s, Batch Size=10, P_Score=0.566]
#
#
# >> Epoch: 118 | Samples Seen: 1170 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.011s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 119 | Samples Seen: 1180 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.012s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 120 | Samples Seen: 1190 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.019s, Batch Size=10, P_Score=0.566]
#
#
# >> Epoch: 121 | Samples Seen: 1200 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.014s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 122 | Samples Seen: 1210 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 123 | Samples Seen: 1220 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 124 | Samples Seen: 1230 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 125 | Samples Seen: 1240 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 126 | Samples Seen: 1250 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 127 | Samples Seen: 1260 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 128 | Samples Seen: 1270 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 129 | Samples Seen: 1280 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 130 | Samples Seen: 1290 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 131 | Samples Seen: 1300 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.028s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 132 | Samples Seen: 1310 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 133 | Samples Seen: 1320 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 134 | Samples Seen: 1330 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 135 | Samples Seen: 1340 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 136 | Samples Seen: 1350 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 137 | Samples Seen: 1360 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 138 | Samples Seen: 1370 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.573]
#
#
# >> Epoch: 139 | Samples Seen: 1380 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 140 | Samples Seen: 1390 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 141 | Samples Seen: 1400 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.573]
#
#
# >> Epoch: 142 | Samples Seen: 1410 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 143 | Samples Seen: 1420 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 144 | Samples Seen: 1430 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.576]
#
#
# >> Epoch: 145 | Samples Seen: 1440 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 146 | Samples Seen: 1450 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 147 | Samples Seen: 1460 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 148 | Samples Seen: 1470 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 149 | Samples Seen: 1480 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.576]
#
#
# >> Epoch: 150 | Samples Seen: 1490 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 151 | Samples Seen: 1500 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 152 | Samples Seen: 1510 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 153 | Samples Seen: 1520 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 154 | Samples Seen: 1530 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 155 | Samples Seen: 1540 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 156 | Samples Seen: 1550 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 157 | Samples Seen: 1560 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 158 | Samples Seen: 1570 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.573]
#
#
# >> Epoch: 159 | Samples Seen: 1580 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.020s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 160 | Samples Seen: 1590 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 161 | Samples Seen: 1600 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 162 | Samples Seen: 1610 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.573]
#
#
# >> Epoch: 163 | Samples Seen: 1620 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 164 | Samples Seen: 1630 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 165 | Samples Seen: 1640 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 166 | Samples Seen: 1650 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 167 | Samples Seen: 1660 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 168 | Samples Seen: 1670 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 169 | Samples Seen: 1680 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.576]
#
#
# >> Epoch: 170 | Samples Seen: 1690 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.576]
#
#
# >> Epoch: 171 | Samples Seen: 1700 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.575]
#
#
# >> Epoch: 172 | Samples Seen: 1710 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 173 | Samples Seen: 1720 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 174 | Samples Seen: 1730 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.576]
#
#
# >> Epoch: 175 | Samples Seen: 1740 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 176 | Samples Seen: 1750 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.574]
#
#
# >> Epoch: 177 | Samples Seen: 1760 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.009s, Batch Size=10, P_Score=0.573]
#
#
# >> Epoch: 178 | Samples Seen: 1770 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 179 | Samples Seen: 1780 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 180 | Samples Seen: 1790 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 181 | Samples Seen: 1800 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 182 | Samples Seen: 1810 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 183 | Samples Seen: 1820 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 184 | Samples Seen: 1830 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 185 | Samples Seen: 1840 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 186 | Samples Seen: 1850 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.067s, Batch Size=10, P_Score=0.569]
#
#
# ...
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 290 | Samples Seen: 2890 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 291 | Samples Seen: 2900 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 292 | Samples Seen: 2910 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 293 | Samples Seen: 2920 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 294 | Samples Seen: 2930 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.016s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 295 | Samples Seen: 2940 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 296 | Samples Seen: 2950 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 297 | Samples Seen: 2960 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 298 | Samples Seen: 2970 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 299 | Samples Seen: 2980 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 300 | Samples Seen: 2990 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 301 | Samples Seen: 3000 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.008s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 302 | Samples Seen: 3010 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.007s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 303 | Samples Seen: 3020 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 304 | Samples Seen: 3030 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 305 | Samples Seen: 3040 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 306 | Samples Seen: 3050 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.006s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 307 | Samples Seen: 3060 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 308 | Samples Seen: 3070 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.561]
#
#
# >> Epoch: 309 | Samples Seen: 3080 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 310 | Samples Seen: 3090 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.562]
#
#
# >> Epoch: 311 | Samples Seen: 3100 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 312 | Samples Seen: 3110 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 313 | Samples Seen: 3120 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.563]
#
#
# >> Epoch: 314 | Samples Seen: 3130 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.564]
#
#
# >> Epoch: 315 | Samples Seen: 3140 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 316 | Samples Seen: 3150 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.565]
#
#
# >> Epoch: 317 | Samples Seen: 3160 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.566]
#
#
# >> Epoch: 318 | Samples Seen: 3170 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 319 | Samples Seen: 3180 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.567]
#
#
# >> Epoch: 320 | Samples Seen: 3190 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 321 | Samples Seen: 3200 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 322 | Samples Seen: 3210 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 323 | Samples Seen: 3220 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 324 | Samples Seen: 3230 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.568]
#
#
# >> Epoch: 325 | Samples Seen: 3240 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 326 | Samples Seen: 3250 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.569]
#
#
# >> Epoch: 327 | Samples Seen: 3260 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 328 | Samples Seen: 3270 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 329 | Samples Seen: 3280 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 330 | Samples Seen: 3290 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 331 | Samples Seen: 3300 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 332 | Samples Seen: 3310 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 333 | Samples Seen: 3320 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 334 | Samples Seen: 3330 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 335 | Samples Seen: 3340 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 336 | Samples Seen: 3350 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 337 | Samples Seen: 3360 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 338 | Samples Seen: 3370 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 339 | Samples Seen: 3380 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 340 | Samples Seen: 3390 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 341 | Samples Seen: 3400 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 342 | Samples Seen: 3410 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.572]
#
#
# >> Epoch: 343 | Samples Seen: 3420 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 344 | Samples Seen: 3430 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 345 | Samples Seen: 3440 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 346 | Samples Seen: 3450 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.57]
#
#
# >> Epoch: 347 | Samples Seen: 3460 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 348 | Samples Seen: 3470 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.034s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 349 | Samples Seen: 3480 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.004s, Batch Size=10, P_Score=0.571]
#
#
# >> Epoch: 350 | Samples Seen: 3490 -------------------------------------------------------------------------------------
# SAIL Pipeline Partial fit: 100%========== [Steps: 3/3, ETA: 00:00<00:00, Elapsed:0.005s, Batch Size=10, P_Score=0.571]

# %% [markdown]
# #### Save SAIL Pipeline

# %%
sail_pipeline.save(".")
# Out:
# './sail_pipeline'

# %% [markdown]
# #### Load SAIL Pipeline

# %%
sail_new_pipeline = SAILPipeline.load(".")
# Out:
# SAIL Pipeline Progressive Score: 100%========== [Points: 3490/3490, Elapsed:0.0065s, Metric=Accuracy, Batch Size=3490, P_Score=0.571]

# %% [markdown]
# #### Make Prediction on the Hold out set

# %%
y_preds = []
y_true = []
batch_size = 100

for start in range(0, X_test.shape[0], batch_size):
    end = start + batch_size

    X = X_test.iloc[start:end]
    y = y_test.iloc[start:end]

    preds = sail_new_pipeline.predict(X)
    y_preds.extend(list(preds))
    y_true.extend(list(y))

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_true, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67       992
#            1       0.34      0.32      0.33       508
#
#     accuracy                           0.56      1500
#    macro avg       0.50      0.50      0.50      1500
# weighted avg       0.55      0.56      0.56      1500

# %% [markdown]
# #### Plot confusion matrix

# %%
import seaborn as sns

cf_matrix = confusion_matrix(y_true, y_preds)
sns.heatmap(cf_matrix / np.sum(cf_matrix), annot=True, fmt=".2%", cmap="Blues")
# Out:
# <Axes: >
